# %% [markdown]
# # hiphop_lyrics Analysis Notebook

# %% [markdown]
# ## Dataset Overview

# %%
import pandas as pd
df = pd.read_csv('../data/hiphop_lyrics.csv')
df.head()

# %% [markdown]
# ## Basic Analysis

# %%
df.describe()
df.info()
df.isna().sum()
